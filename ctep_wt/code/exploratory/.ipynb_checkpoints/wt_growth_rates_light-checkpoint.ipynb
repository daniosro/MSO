# %%
# For numerical calculations
import numpy as np
import pandas as pd
import scipy as sp
import math
import matplotlib.animation as animation
from scipy.integrate import odeint
from numpy.random import randint
from numpy import arange
from pylab import *
from scipy.integrate import odeint
import scipy.optimize 
from scipy.optimize import leastsq
from math import exp
from collections import OrderedDict
from sklearn.linear_model import LinearRegression
pd.options.mode.chained_assignment = None
import git

# Find home directory for repo
repo = git.Repo("./", search_parent_directories=True)
homedir = repo.working_dir

# Import plotting features
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style
sns.set_style("ticks")
sns.set_palette("colorblind", color_codes=True)
sns.set_context("paper")

# Magic command to plot inline
# %matplotlib inline

#To graph in SVG (high def)
# %config InlineBackend.figure_format="svg"

# %%
# Import table with data
df_data =  pd.read_csv(f'{homedir}/d_alk/data/raw/growth/20210906_growth.csv') 
#See data
df_data.head(200)
# Out:
#      Time_h  Timepoint Treatment  Replicate   OD600    cells_ml  Sulfide_mM
# 0       0.0        0.0    Medium          1  0.0000   1000000.0    4.634866
# 1       0.0        0.0    Medium          1  0.0000   1000000.0    4.901377
# 2       0.0        0.0    Medium          1  0.0000   1000000.0    4.466257
# 3       0.0        0.0    Medium          2  0.0000   1000000.0    4.634866
# 4       0.0        0.0    Medium          2  0.0000   1000000.0    4.901377
# ..      ...        ...       ...        ...     ...         ...         ...
# 195   135.0        NaN       Low          4  0.0349  34120100.0         NaN
# 196   135.0        NaN     Lower          4  0.0378  37968400.0         NaN
# 197   135.0        NaN      None          4  0.0301  28120100.0         NaN
# 198   135.0        NaN      None          5  0.0311  29332100.0         NaN
# 199   135.0        NaN      None          6  0.0312  29454400.0         NaN
#
# [200 rows x 7 columns]

# %%
# Calculate the mean and standard deviation                           
df_growth = df_data.groupby(['Treatment', 'Replicate','Time_h']).agg(
                    {'cells_ml':['mean'],
                     'Sulfide_mM':['mean','std']})
#Change non existing values to 0
#df_group = df_group.fillna(0)
#Rename columns after agg
df_growth.columns = ["_".join(x) for x in df_growth.columns.ravel()]
#Drop first level of table after agg
df_growth = df_growth.reset_index()
df_growth
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#     Treatment  Replicate  Time_h  cells_ml_mean  Sulfide_mM_mean  \
# 0         Low          1     0.0      1000000.0         3.710236
# 1         Low          1    18.5      5690000.0         2.459266
# 2         Low          1    23.5      4531600.0         1.711403
# 3         Low          1    27.0     13206025.0         1.346084
# 4         Low          1    33.0     21648025.0         0.657144
# ..        ...        ...     ...            ...              ...
# 98       None          5    84.0     26105600.0              NaN
# 99       None          5   135.0     29332100.0              NaN
# 100      None          6    60.0     14090000.0              NaN
# 101      None          6    84.0     20944400.0              NaN
# 102      None          6   135.0     29454400.0              NaN
#
#      Sulfide_mM_std
# 0          0.227725
# 1          0.128595
# 2          0.088457
# 3          0.063039
# 4          0.021981
# ..              ...
# 98              NaN
# 99              NaN
# 100             NaN
# 101             NaN
# 102             NaN
#
# [103 rows x 6 columns]

# %% [markdown]
# ## Plots of cells and concentrations vs. time

# %% [markdown]
# ### Medium

# %%
#Make a plot of cells and concentrations vs. time for medium
#Filter by medium
df_medium= df_growth[(df_growth.Treatment == 'Medium')]
# Group by replicate
df_treatments = df_medium.groupby(['Replicate'])
# Define colors
colors = sns.color_palette('colorblind', n_colors=5)
# Define markers
markers = ['d', 'o','.','s','x']

# Define fig and axes
#fig, ax = plt.subplots(1,7, figsize=(9,6))
fig = plt.figure(figsize=(2.95, 1.95), dpi=192)
ax = fig.add_subplot(111)
# twin object for two different y-axis on the sample plot
ax2=ax.twinx()

# Loop through replicates
for i, (group, data) in enumerate(df_treatments):
    #print(group, data)
    ax.scatter(data.Time_h, data.cells_ml_mean,color=colors[i], marker=markers[i], label = group)
    ax2.errorbar(data.Time_h, data.Sulfide_mM_mean, yerr=data.Sulfide_mM_std, color=colors[4], marker=markers[i])
    ax.set_xlabel('Time (h)')
    ax.set_ylabel('Cells/ml')
    #ax2.set_ylabel('Sulfide (mM)', color=colors[1])
    ax.set_title('Medium', size=12)
    ax.set_yscale('log')
    #ax.set_ylim([8e5, 7e8])

#Show legend
plt.legend(bbox_to_anchor=(1.2, 1), loc='upper left', borderaxespad=0.)
#Save figure
#fig.savefig(f'{homedir}/ctep_wt/figures/full_cells.pdf', bbox_inches='tight')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Get growth rates for medium
#Filter medium dataframe for exponential phase only
df_medium_exp_mean = df_medium[(df_medium.Time_h <= 36)]
df_medium_exp_mean.head()
# Out:
#    Treatment  Replicate  Time_h  cells_ml_mean  Sulfide_mM_mean  \
# 46    Medium          1     0.0   1.000000e+06         4.667500
# 47    Medium          1    18.5   1.000000e+06         2.675013
# 48    Medium          1    23.5   4.484444e+06         2.040463
# 49    Medium          1    27.0   1.238522e+07         1.666985
# 50    Medium          1    33.0   1.710010e+07         0.697030
#
#     Sulfide_mM_std
# 46        0.219388
# 47        0.086399
# 48        0.184606
# 49        0.064889
# 50        0.027195

# %%
#Get ratios of cells/ml calculated from chlorophyll between timepoints for each ID and Replicate
df_medium_exp_mean['ratio_cells'] = df_medium_exp_mean['cells_ml_mean'].div(df_medium_exp_mean.groupby(['Treatment','Replicate'])['cells_ml_mean'].shift(1)).fillna(0) 
#Get differences between timepoints for each treatment and Replicate
df_medium_exp_mean['diff_time_h'] = df_medium_exp_mean.groupby(['Treatment','Replicate'])['Time_h'].diff().fillna(0)
#Get differences between cells/ml between timepoints for each treatment and Replicate
df_medium_exp_mean['diff_cells'] = df_medium_exp_mean.groupby(['Treatment','Replicate'])['cells_ml_mean'].diff().fillna(0)
#Get differences between sulfide concentrations between timepoints for each ID and Replicate
df_medium_exp_mean['diff_sulfide_mM'] = df_medium_exp_mean.groupby(['Treatment','Replicate'])['Sulfide_mM_mean'].diff().fillna(0)
#Calculate growth rates in day^-1
df_medium_exp_mean['growth_rate'] = np.log(df_medium_exp_mean['ratio_cells'])*24/df_medium_exp_mean['diff_time_h']
#Get maximum growth rates per ID and Replicate
df_medium_exp_mean['max_growth_rate']= df_medium_exp_mean.groupby(['Treatment','Replicate'])['growth_rate'].transform(max)
#Determine csSOR
df_medium_exp_mean['csSOR'] = -(df_medium_exp_mean['max_growth_rate']*df_medium_exp_mean['diff_sulfide_mM']*10**9)/df_medium_exp_mean['diff_cells']
#See dataframe
df_medium_exp_mean
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#    Treatment  Replicate  Time_h  cells_ml_mean  Sulfide_mM_mean  \
# 46    Medium          1     0.0   1.000000e+06         4.667500
# 47    Medium          1    18.5   1.000000e+06         2.675013
# 48    Medium          1    23.5   4.484444e+06         2.040463
# 49    Medium          1    27.0   1.238522e+07         1.666985
# 50    Medium          1    33.0   1.710010e+07         0.697030
# 51    Medium          1    36.0   2.302490e+07         0.000000
# 52    Medium          2     0.0   1.000000e+06         4.667500
# 53    Medium          2    18.5   3.000278e+06         2.582550
# 54    Medium          2    23.5   1.384004e+07         2.114796
# 55    Medium          2    27.0   1.288490e+07         1.585400
# 56    Medium          2    33.0   1.806102e+07         0.719398
# 57    Medium          2    36.0   2.137640e+07         0.000000
# 58    Medium          3     0.0   1.000000e+06         4.667500
# 59    Medium          3    18.5   5.690000e+06         2.834557
# 60    Medium          3    23.5   9.864711e+06         2.033211
# 61    Medium          3    27.0   1.057610e+07         1.590839
# 62    Medium          3    33.0   1.695002e+07         0.633609
# 63    Medium          3    36.0   2.072960e+07         0.000000
#
#     Sulfide_mM_std  ratio_cells  diff_time_h  diff_cells_chl  diff_sulfide_mM  \
# 46        0.219388     0.000000          0.0    0.000000e+00         0.000000
# 47        0.086399     1.000000         18.5    0.000000e+00        -1.992487
# 48        0.184606     4.484444          5.0    3.484444e+06        -0.634550
# 49        0.064889     2.761819          3.5    7.900781e+06        -0.373478
# 50        0.027195     1.380685          6.0    4.714875e+06        -0.969955
# 51             NaN     1.346478          3.0    5.924800e+06        -0.697030
# 52        0.219388     0.000000          0.0    0.000000e+00         0.000000
# 53        0.226705     3.000278         18.5    2.000278e+06        -2.084950
# 54        0.087420     4.612921          5.0    1.083977e+07        -0.467754
# 55        0.105513     0.930987          3.5   -9.551444e+05        -0.529396
# 56        0.037742     1.401720          6.0    5.176125e+06        -0.866002
# 57             NaN     1.183565          3.0    3.315375e+06        -0.719398
# 58        0.219388     0.000000          0.0    0.000000e+00         0.000000
# 59        0.120274     5.690000         18.5    4.690000e+06        -1.832943
# 60        0.139977     1.733693          5.0    4.174711e+06        -0.801346
# 61        0.107458     1.072115          3.5    7.113889e+05        -0.442372
# 62        0.011322     1.602673          6.0    6.373925e+06        -0.957230
# 63             NaN     1.222983          3.0    3.779575e+06        -0.633609
#
#     growth_rate  max_growth_rate        csSOR
# 46         -inf         7.202950          NaN
# 47     0.000000         7.202950          inf
# 48     7.202950         7.202950  1311.724753
# 49     6.966100         7.202950   340.490842
# 50     1.290320         7.202950  1481.807583
# 51     2.379935         7.202950   847.399466
# 52         -inf         7.338534          NaN
# 53     1.425347         7.338534  7649.176016
# 54     7.338534         7.338534   316.669982
# 55    -0.490355         7.338534 -4067.437834
# 56     1.350801         7.338534  1227.788685
# 57     1.348250         7.338534  1592.376233
# 58         -inf         2.641217          NaN
# 59     2.255624         2.641217  1032.238973
# 60     2.641217         2.641217   506.988118
# 61     0.477483         2.641217  1642.421751
# 62     1.886690         2.641217   396.655506
# 63     1.610347         2.641217   442.774402

# %%
#Get growth rates for the entire exponential phase
#Filter medium dataframe for exponential phase only (t=0 and t=36h)
df_medium_exp = df_medium[(df_medium.Time_h == 0) | (df_medium.Time_h == 36)]
df_medium_exp.head(20)
# Out:
#    Treatment  Replicate  Time_h  cells_ml_mean  Sulfide_mM_mean  \
# 46    Medium          1     0.0      1000000.0           4.6675
# 51    Medium          1    36.0     23024900.0           0.0000
# 52    Medium          2     0.0      1000000.0           4.6675
# 57    Medium          2    36.0     21376400.0           0.0000
# 58    Medium          3     0.0      1000000.0           4.6675
# 63    Medium          3    36.0     20729600.0           0.0000
#
#     Sulfide_mM_std
# 46        0.219388
# 51             NaN
# 52        0.219388
# 57             NaN
# 58        0.219388
# 63             NaN

# %%
#Get ratios of cells/ml calculated from chlorophyll between timepoints for each ID and Replicate
df_medium_exp['ratio_cells'] = df_medium_exp['cells_ml_mean'].div(df_medium_exp.groupby(['Treatment','Replicate'])['cells_ml_mean'].shift(1)).fillna(0) 
#Get differences between timepoints for each treatment and Replicate
df_medium_exp['diff_time_h'] = df_medium_exp.groupby(['Treatment','Replicate'])['Time_h'].diff().fillna(0)
#Get differences between cells/ml between timepoints for each treatment and Replicate
df_medium_exp['diff_cells'] = df_medium_exp.groupby(['Treatment','Replicate'])['cells_ml_mean'].diff().fillna(0)
#Get differences between sulfide concentrations between timepoints for each ID and Replicate
df_medium_exp['diff_sulfide_mM'] = df_medium_exp.groupby(['Treatment','Replicate'])['Sulfide_mM_mean'].diff().fillna(0)
#Calculate growth rates in day^-1
df_medium_exp['growth_rate'] = np.log(df_medium_exp['ratio_cells'])*24/df_medium_exp['diff_time_h']
#Get maximum growth rates per ID and Replicate
df_medium_exp['max_growth_rate']= df_medium_exp.groupby(['Treatment','Replicate'])['growth_rate'].transform(max)
#Determine csSOR
df_medium_exp['csSOR'] = -(df_medium_exp['max_growth_rate']*df_medium_exp['diff_sulfide_mM']*10**9)/df_medium_exp['diff_cells']
#See dataframe
df_medium_exp
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#    Treatment  Replicate  Time_h  cells_ml_mean  Sulfide_mM_mean  \
# 46    Medium          1     0.0      1000000.0           4.6675
# 51    Medium          1    36.0     23024900.0           0.0000
# 52    Medium          2     0.0      1000000.0           4.6675
# 57    Medium          2    36.0     21376400.0           0.0000
# 58    Medium          3     0.0      1000000.0           4.6675
# 63    Medium          3    36.0     20729600.0           0.0000
#
#     Sulfide_mM_std  ratio_cells  diff_time_h  diff_cells  diff_sulfide_mM  \
# 46        0.219388       0.0000          0.0         0.0           0.0000
# 51             NaN      23.0249         36.0  22024900.0          -4.6675
# 52        0.219388       0.0000          0.0         0.0           0.0000
# 57             NaN      21.3764         36.0  20376400.0          -4.6675
# 58        0.219388       0.0000          0.0         0.0           0.0000
# 63             NaN      20.7296         36.0  19729600.0          -4.6675
#
#     growth_rate  max_growth_rate       csSOR
# 46         -inf         2.091051         NaN
# 51     2.091051         2.091051  443.133895
# 52         -inf         2.041525         NaN
# 57     2.041525         2.041525  467.639915
# 58         -inf         2.021042         NaN
# 63     2.021042         2.021042  478.124867

# %%
# Calculate the mean and standard deviation  
df_medium_exp_36 = df_medium_exp[(df_medium_exp.Time_h == 36)]
df_stats_medium = df_medium_exp_36.agg(
                    {'max_growth_rate':['mean','std'],
                     'csSOR':['mean','std']})
df_stats_medium
# Out:
#       max_growth_rate       csSOR
# mean         2.051206  462.966226
# std          0.035995   17.957577

# %% [markdown]
# ### Low

# %%
#Make a plot of cells and concentrations vs. time for Low
#Filter by Low
df_low= df_growth[(df_growth.Treatment == 'Low')]
# Group by replicate
df_treatments = df_low.groupby(['Replicate'])
# Define colors
colors = sns.color_palette('colorblind', n_colors=4)
# Define markers
markers = ['d', 'o','.','s','x']

# Define fig and axes
#fig, ax = plt.subplots(1,7, figsize=(9,6))
fig = plt.figure(figsize=(2.95, 1.95), dpi=192)
ax = fig.add_subplot(111)

# Loop through replicates
for i, (group, data) in enumerate(df_treatments):
    #print(group, data)
    ax.scatter(data.Time_h, data.cells_ml_mean,color=colors[i], marker=markers[i],
              label = group)
    ax.set_xlabel('Time (h)')
    ax.set_ylabel('Cells/ml')
    ax.set_title('Low', size=12)
    ax.set_yscale('log')
    #ax.set_ylim([8e5, 7e8])

#Show legend
plt.legend(bbox_to_anchor=(1.2, 1), loc='upper left', borderaxespad=0.)
#Save figure

# %%
#Get growth rates for the entire exponential phase
#Filter low dataframe for exponential phase only (t=0 and t=36h)
df_low_exp = df_low[(df_low.Time_h == 0) | (df_low.Time_h == 36)]
df_low_exp.head(20)
# Out:
#    Treatment  Replicate  Time_h  cells_ml_mean  Sulfide_mM_mean  \
# 0        Low          1     0.0      1000000.0         3.710236
# 5        Low          1    36.0     25524100.0         0.000000
# 6        Low          2     0.0      1000000.0         3.710236
# 11       Low          2    36.0     28000000.0         0.000000
# 12       Low          3     0.0      1000000.0         3.710236
# 17       Low          3    36.0     24718400.0         0.000000
#
#     Sulfide_mM_std
# 0         0.227725
# 5              NaN
# 6         0.227725
# 11             NaN
# 12        0.227725
# 17             NaN

# %%
#Get ratios of cells/ml calculated from chlorophyll between timepoints for each ID and Replicate
df_low_exp['ratio_cells'] = df_low_exp['cells_ml_mean'].div(df_low_exp.groupby(['Treatment','Replicate'])['cells_ml_mean'].shift(1)).fillna(0) 
#Get differences between timepoints for each treatment and Replicate
df_low_exp['diff_time_h'] = df_low_exp.groupby(['Treatment','Replicate'])['Time_h'].diff().fillna(0)
#Get differences between cells/ml between timepoints for each treatment and Replicate
df_low_exp['diff_cells'] = df_low_exp.groupby(['Treatment','Replicate'])['cells_ml_mean'].diff().fillna(0)
#Get differences between sulfide concentrations between timepoints for each ID and Replicate
df_low_exp['diff_sulfide_mM'] = df_low_exp.groupby(['Treatment','Replicate'])['Sulfide_mM_mean'].diff().fillna(0)
#Calculate growth rates in day^-1
df_low_exp['growth_rate'] = np.log(df_low_exp['ratio_cells'])*24/df_low_exp['diff_time_h']
#Get maximum growth rates per ID and Replicate
df_low_exp['max_growth_rate']= df_low_exp.groupby(['Treatment','Replicate'])['growth_rate'].transform(max)
#Determine csSOR
df_low_exp['csSOR'] = -(df_low_exp['max_growth_rate']*df_low_exp['diff_sulfide_mM']*10**9)/df_low_exp['diff_cells']
#See dataframe
df_low_exp
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#    Treatment  Replicate  Time_h  cells_ml_mean  Sulfide_mM_mean  \
# 0        Low          1     0.0      1000000.0         3.710236
# 5        Low          1    36.0     25524100.0         0.000000
# 6        Low          2     0.0      1000000.0         3.710236
# 11       Low          2    36.0     28000000.0         0.000000
# 12       Low          3     0.0      1000000.0         3.710236
# 17       Low          3    36.0     24718400.0         0.000000
#
#     Sulfide_mM_std  ratio_cells  diff_time_h  diff_cells  diff_sulfide_mM  \
# 0         0.227725       0.0000          0.0         0.0         0.000000
# 5              NaN      25.5241         36.0  24524100.0        -3.710236
# 6         0.227725       0.0000          0.0         0.0         0.000000
# 11             NaN      28.0000         36.0  27000000.0        -3.710236
# 12        0.227725       0.0000          0.0         0.0         0.000000
# 17             NaN      24.7184         36.0  23718400.0        -3.710236
#
#     growth_rate  max_growth_rate       csSOR
# 0          -inf         2.159749         NaN
# 5      2.159749         2.159749  326.747057
# 6          -inf         2.221470         NaN
# 11     2.221470         2.221470  305.265806
# 12         -inf         2.138365         NaN
# 17     2.138365         2.138365  334.501476

# %%
# Calculate the mean and standard deviation  
df_low_exp_36 = df_low_exp[(df_low_exp.Time_h == 36)]
df_stats_low = df_low_exp_36.agg(
                    {'max_growth_rate':['mean','std'],
                     'csSOR':['mean','std']})
df_stats_low
# Out:
#       max_growth_rate       csSOR
# mean         2.173195  322.171446
# std          0.043153   15.145404

# %% [markdown]
# ### Lower

# %%
#Make a plot of cells and concentrations vs. time for Lower
#Filter by Lower
df_lower= df_growth[(df_growth.Treatment == 'Lower')]
# Group by replicate
df_treatments = df_lower.groupby(['Replicate'])
# Define colors
colors = sns.color_palette('colorblind', n_colors=4)
# Define markers
markers = ['d', 'o','.','s','x']

# Define fig and axes
#fig, ax = plt.subplots(1,7, figsize=(9,6))
fig = plt.figure(figsize=(2.95, 1.95), dpi=192)
ax = fig.add_subplot(111)

# Loop through replicates
for i, (group, data) in enumerate(df_treatments):
    #print(group, data)
    ax.scatter(data.Time_h, data.cells_ml_mean,color=colors[i], marker=markers[i],
              label = group)
    ax.set_xlabel('Time (h)')
    ax.set_ylabel('Cells/ml')
    ax.set_title('Lower', size=12)
    ax.set_yscale('log')
    #ax.set_ylim([8e5, 7e8])

#Show legend
plt.legend(bbox_to_anchor=(1.2, 1), loc='upper left', borderaxespad=0.)
#Save figure

# %%
#Get growth rates for the entire exponential phase
#Filter lower dataframe for exponential phase only (t=0 and t=36h)
df_lower_exp = df_lower[(df_lower.Time_h == 0) | (df_lower.Time_h == 36)]
df_lower_exp.head(20)
# Out:
#    Treatment  Replicate  Time_h  cells_ml_mean  Sulfide_mM_mean  \
# 23     Lower          1     0.0      1000000.0         1.777578
# 28     Lower          1    36.0     17704900.0         0.474031
# 29     Lower          2     0.0      1000000.0         1.777578
# 34     Lower          2    36.0      9056900.0         0.474031
# 35     Lower          3     0.0      1000000.0         1.777578
# 40     Lower          3    36.0     16108100.0         0.463153
#
#     Sulfide_mM_std
# 23        0.125255
# 28             NaN
# 29        0.125255
# 34             NaN
# 35        0.125255
# 40             NaN

# %%
#Get ratios of cells/ml calculated from chlorophyll between timepoints for each ID and Replicate
df_lower_exp['ratio_cells'] = df_lower_exp['cells_ml_mean'].div(df_lower_exp.groupby(['Treatment','Replicate'])['cells_ml_mean'].shift(1)).fillna(0) 
#Get differences between timepoints for each treatment and Replicate
df_lower_exp['diff_time_h'] = df_lower_exp.groupby(['Treatment','Replicate'])['Time_h'].diff().fillna(0)
#Get differences between cells/ml between timepoints for each treatment and Replicate
df_lower_exp['diff_cells'] = df_lower_exp.groupby(['Treatment','Replicate'])['cells_ml_mean'].diff().fillna(0)
#Get differences between sulfide concentrations between timepoints for each ID and Replicate
df_lower_exp['diff_sulfide_mM'] = df_lower_exp.groupby(['Treatment','Replicate'])['Sulfide_mM_mean'].diff().fillna(0)
#Calculate growth rates in day^-1
df_lower_exp['growth_rate'] = np.log(df_lower_exp['ratio_cells'])*24/df_lower_exp['diff_time_h']
#Get maximum growth rates per ID and Replicate
df_lower_exp['max_growth_rate']= df_lower_exp.groupby(['Treatment','Replicate'])['growth_rate'].transform(max)
#Determine csSOR
df_lower_exp['csSOR'] = -(df_lower_exp['max_growth_rate']*df_lower_exp['diff_sulfide_mM']*10**9)/df_lower_exp['diff_cells']
#See dataframe
df_lower_exp
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#    Treatment  Replicate  Time_h  cells_ml_mean  Sulfide_mM_mean  \
# 23     Lower          1     0.0      1000000.0         1.777578
# 28     Lower          1    36.0     17704900.0         0.474031
# 29     Lower          2     0.0      1000000.0         1.777578
# 34     Lower          2    36.0      9056900.0         0.474031
# 35     Lower          3     0.0      1000000.0         1.777578
# 40     Lower          3    36.0     16108100.0         0.463153
#
#     Sulfide_mM_std  ratio_cells  diff_time_h  diff_cells  diff_sulfide_mM  \
# 23        0.125255       0.0000          0.0         0.0         0.000000
# 28             NaN      17.7049         36.0  16704900.0        -1.303547
# 29        0.125255       0.0000          0.0         0.0         0.000000
# 34             NaN       9.0569         36.0   8056900.0        -1.303547
# 35        0.125255       0.0000          0.0         0.0         0.000000
# 40             NaN      16.1081         36.0  15108100.0        -1.314425
#
#     growth_rate  max_growth_rate       csSOR
# 23         -inf         1.915894         NaN
# 28     1.915894         1.915894  149.504532
# 29         -inf         1.469018         NaN
# 34     1.469018         1.469018  237.676267
# 35         -inf         1.852882         NaN
# 40     1.852882         1.852882  161.203180

# %%
# Calculate the mean and standard deviation  
df_lower_exp_36 = df_lower_exp[(df_lower_exp.Time_h == 36)]
df_stats_lower = df_lower_exp_36.agg(
                    {'max_growth_rate':['mean','std'],
                     'csSOR':['mean','std']})
df_stats_lower
# Out:
#       max_growth_rate       csSOR
# mean         1.745931  182.794660
# std          0.241875   47.887449

# %% [markdown]
# ### None

# %%
#Make a plot of cells and concentrations vs. time for None
#Filter by None
df_none= df_growth[(df_growth.Treatment == 'None')]
# Group by replicate
df_treatments = df_none.groupby(['Replicate'])
# Define colors
colors = sns.color_palette('colorblind', n_colors=6)
# Define markers
markers = ['d', 'o','.','s','x','X']

# Define fig and axes
#fig, ax = plt.subplots(1,7, figsize=(9,6))
fig = plt.figure(figsize=(2.95, 1.95), dpi=192)
ax = fig.add_subplot(111)

# Loop through replicates
for i, (group, data) in enumerate(df_treatments):
    #print(group, data)
    ax.scatter(data.Time_h, data.cells_ml_mean,color=colors[i], marker=markers[i],
              label = group)
    ax.set_xlabel('Time (h)')
    ax.set_ylabel('Cells/ml')
    ax.set_title('None', size=12)
    ax.set_yscale('log')
    #ax.set_ylim([8e5, 7e8])

#Show legend
plt.legend(bbox_to_anchor=(1.2, 1), loc='upper left', borderaxespad=0.)
#Save figure

# %%
#Get growth rates for the entire exponential phase
#Filter none dataframe for exponential phase only (t=0 and t=36h)
df_none_exp = df_none[(df_none.Time_h == 0) | (df_none.Time_h == 36)]
df_none_exp.head(20)
# Out:
#    Treatment  Replicate  Time_h  cells_ml_mean  Sulfide_mM_mean  \
# 70      None          1     0.0      1000000.0         3.068434
# 75      None          1    36.0     12340100.0         0.978045
# 78      None          2     0.0      1000000.0         3.068434
# 83      None          2    36.0      2824100.0         0.914590
# 86      None          3     0.0      1000000.0         3.068434
# 91      None          3    36.0      9892900.0         0.818501
#
#     Sulfide_mM_std
# 70        0.051885
# 75        0.068870
# 78        0.051885
# 83        0.117664
# 86        0.051885
# 91        0.094572

# %%
#Get ratios of cells/ml calculated from chlorophyll between timepoints for each ID and Replicate
df_none_exp['ratio_cells'] = df_none_exp['cells_ml_mean'].div(df_none_exp.groupby(['Treatment','Replicate'])['cells_ml_mean'].shift(1)).fillna(0) 
#Get differences between timepoints for each treatment and Replicate
df_none_exp['diff_time_h'] = df_none_exp.groupby(['Treatment','Replicate'])['Time_h'].diff().fillna(0)
#Get differences between cells/ml between timepoints for each treatment and Replicate
df_none_exp['diff_cells'] = df_none_exp.groupby(['Treatment','Replicate'])['cells_ml_mean'].diff().fillna(0)
#Get differences between sulfide concentrations between timepoints for each ID and Replicate
df_none_exp['diff_sulfide_mM'] = df_none_exp.groupby(['Treatment','Replicate'])['Sulfide_mM_mean'].diff().fillna(0)
#Calculate growth rates in day^-1
df_none_exp['growth_rate'] = np.log(df_none_exp['ratio_cells'])*24/df_none_exp['diff_time_h']
#Get maximum growth rates per ID and Replicate
df_none_exp['max_growth_rate']= df_none_exp.groupby(['Treatment','Replicate'])['growth_rate'].transform(max)
#Determine csSOR
df_none_exp['csSOR'] = -(df_none_exp['max_growth_rate']*df_none_exp['diff_sulfide_mM']*10**9)/df_none_exp['diff_cells']
#See dataframe
df_none_exp
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#    Treatment  Replicate  Time_h  cells_ml_mean  Sulfide_mM_mean  \
# 70      None          1     0.0      1000000.0         3.068434
# 75      None          1    36.0     12340100.0         0.978045
# 78      None          2     0.0      1000000.0         3.068434
# 83      None          2    36.0      2824100.0         0.914590
# 86      None          3     0.0      1000000.0         3.068434
# 91      None          3    36.0      9892900.0         0.818501
#
#     Sulfide_mM_std  ratio_cells  diff_time_h  diff_cells  diff_sulfide_mM  \
# 70        0.051885       0.0000          0.0         0.0         0.000000
# 75        0.068870      12.3401         36.0  11340100.0        -2.090389
# 78        0.051885       0.0000          0.0         0.0         0.000000
# 83        0.117664       2.8241         36.0   1824100.0        -2.153844
# 86        0.051885       0.0000          0.0         0.0         0.000000
# 91        0.094572       9.8929         36.0   8892900.0        -2.249933
#
#     growth_rate  max_growth_rate       csSOR
# 70         -inf         1.675236         NaN
# 75     1.675236         1.675236  308.806367
# 78         -inf         0.692126         NaN
# 83     0.692126         0.692126  817.242739
# 86         -inf         1.527878         NaN
# 91     1.527878         1.527878  386.558223

# %%
# Calculate the mean and standard deviation  
df_none_exp_36 = df_none_exp[(df_none_exp.Time_h == 36) & (df_none_exp.Replicate != 2)]
df_stats_none = df_none_exp_36.agg(
                    {'max_growth_rate':['mean','std'],
                     'csSOR':['mean','std']})
df_stats_none
# Out:
#       max_growth_rate       csSOR
# mean         1.601557  347.682295
# std          0.104198   54.978865
